# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/서울시 강서구 휴게음식점 인허가 정보.csv',  encoding='cp949')

# %%
print(df.shape)
df.head()
# Out:
# (589, 44)
#    개방자치단체코드                    관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0   3150000  3150000-104-1991-08073  19911226      NaN       3     폐업
# 1   3150000  3150000-104-1992-06930  19920110      NaN       3     폐업
# 2   3150000  3150000-104-1993-06931  19930925      NaN       3     폐업
# 3   3150000  3150000-104-1993-06932  19931029      NaN       3     폐업
# 4   3150000  3150000-104-1993-06933  19931101      NaN       1  영업/정상
#
#    상세영업상태코드 상세영업상태명      폐업일자  휴업시작일자  ...  공장판매직종업원수  공장생산직종업원수 건물소유구분명  보증액  \
# 0         2      폐업  20021230     NaN  ...        NaN        NaN     NaN  NaN
# 1         2      폐업  19981028     NaN  ...        NaN        NaN     NaN  NaN
# 2         2      폐업  20130723     NaN  ...        NaN        NaN     NaN  NaN
# 3         2      폐업  20100226     NaN  ...        NaN        NaN     NaN  NaN
# 4         1      영업       NaN     NaN  ...        0.0        0.0     NaN  0.0
#
#    월세액 다중이용업소여부  시설총규모  전통업소지정번호 전통업소주된음식 홈페이지
# ...

# %%
df.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수',
#        '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수', '공장사무직종업원수',
#        '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모',
#        '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
df = df.drop(columns = ['개방자치단체코드','관리번호','인허가일자', '인허가취소일자','영업상태코드','상세영업상태코드',
       '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호','최종수정일자', '데이터갱신구분',
       '데이터갱신일자','업태구분명','위생업태명', '남성종사자수', '여성종사자수',
       '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수', '공장사무직종업원수',
       '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모',
       '전통업소지정번호', '전통업소주된음식', '홈페이지','도로명주소', '도로명우편번호'])
df = df.dropna()
print(df.shape)
df.head()
# Out:
# (553, 7)
#    영업상태명  소재지면적 소재지우편번호                      지번주소       사업장명      좌표정보(X)  \
# 0     폐업  66.17  157918   서울특별시 강서구 화곡동 1008-0번지   미니스톱화곡3호점  185210.8676
# 1     폐업   23.5  157870     서울특별시 강서구 화곡동 84-1번지     미니스톱화곡점  186154.1887
# 2     폐업  17.65  157863    서울특별시 강서구 염창동 272-9번지          럭키  188182.7894
# 3     폐업  11.83  157924  서울특별시 강서구 화곡동 1067-18번지     훼미리화곡본동  185495.1431
# 4  영업/정상   8.02  157812      서울특별시 강서구 공항동 60-31       LG25시  183211.7113
#
#        좌표정보(Y)
# 0  449521.3548
# 1  449418.0345
# 2  449782.3289
# 3  448778.8315
# 4  450672.5540

# %%
df = df[df['영업상태명'] == '영업/정상']
print(df.shape)
df.head()
# Out:
# (297, 7)
#     영업상태명 소재지면적  소재지우편번호                              지번주소          사업장명  \
# 4   영업/정상  8.02   157812              서울특별시 강서구 공항동 60-31          LG25시
# 18  영업/정상  5.11   157850              서울특별시 강서구 방화동 559-5       바이더웨이공항점
# 30  영업/정상  8.55   157842           서울특별시 강서구 등촌동 655-27번지          훼미리마트
# 56  영업/정상   2.2  157-831     서울특별시 강서구 내발산동 699-19 (지상 1층)    세븐일레븐(발산점)
# 58  영업/정상  8.59  157-930  서울특별시 강서구 등촌동 683-0 인방빌딩 (지상 1층)  세븐일레븐(등촌5호점)
#
#         좌표정보(X)      좌표정보(Y)
# 4   183211.7113  450672.5540
# 18  183147.7757  452259.1121
# 30  187146.1253  450413.6462
# 56  185332.4742  450055.4159
# 58  185932.0354  451560.5369

# %%
import re

def extract_dong(address):
    match = re.search(r'\s[\w가-힣]+동', address)
    if match:
        return match.group().strip()
    return None

# 데이터 프레임의 '지번주소' 열에 함수 적용
df['행정동'] = df['지번주소'].apply(extract_dong)
df = df.drop(columns = '동 이름')

df.head()
# Out:
#     영업상태명 소재지면적  소재지우편번호                              지번주소          사업장명  \
# 4   영업/정상  8.02   157812              서울특별시 강서구 공항동 60-31          LG25시
# 18  영업/정상  5.11   157850              서울특별시 강서구 방화동 559-5       바이더웨이공항점
# 30  영업/정상  8.55   157842           서울특별시 강서구 등촌동 655-27번지          훼미리마트
# 56  영업/정상   2.2  157-831     서울특별시 강서구 내발산동 699-19 (지상 1층)    세븐일레븐(발산점)
# 58  영업/정상  8.59  157-930  서울특별시 강서구 등촌동 683-0 인방빌딩 (지상 1층)  세븐일레븐(등촌5호점)
#
#         좌표정보(X)      좌표정보(Y)   행정동
# 4   183211.7113  450672.5540   공항동
# 18  183147.7757  452259.1121   방화동
# 30  187146.1253  450413.6462   등촌동
# 56  185332.4742  450055.4159  내발산동
# 58  185932.0354  451560.5369   등촌동

# %%
df.to_csv('강서구 편의점 행정동 전처리.csv', index=False)
